# %%
balance=10000
print("**welcome to SBI**")
print("!insert your card!")
amount=int(input("enter the amount: "))
pin=int(input("enter your pin: "))
## withdraw money
if balance>=amount:
    balance=balance-amount
    print("**collect your amount and card**")
    print("your current balance is: ",balance)
else:
    print(" sorry! insufficient balance")
    print()

## deposite money
print("deposite opreation")
deposite_amount=int(input("depositemount:"))
balance = balance+deposite_amount
print("your money has been successfully desposite.")
print("now your current balance is" ,balance)
# Out:
# **welcome to SBI**
# !insert your card!
# enter the amount:  5600
# enter your pin:  2345
# **collect your amount and card**
# your current balance is:  4400
# deposite opreation
# depositemount: 12000
# your money has been successfully desposite.
# now your current balance is 16400

# %%
balance=10000000
class Bank_atm():
    def __init__(self,balance):
        self.balance=balance
        print("**welcome to SBI**")
        print("!insert your card!")
      
## withdraw money
    def  withdraw_amount(self):
       
        withdraw=int(input("enter your withdraw amount"))
        if self.balance >= withdraw:
           self.balance -= withdraw
           print("your current balance is: ",self.balance)
           print("**collect your amount and card**")
        else:
           print(" sorry! insufficient balance")
           print()

## deposite money
    def deposite_amount(self):
         
         print("deposite opreation")
         deposite_amount=int(input(" enter your deposite deposite amount:"))
         self.balance += deposite_amount
         print("your money has been successfully desposite.")
       
    def check_amount(self):
        print("Net balance is ",self.balance)

if __name__ =="__main__":
   b= Bank_atm(balance)

   b.withdraw_amount()
   b.deposite_amount()
   b.check_amount()
# Out:
# **welcome to SBI**
# !insert your card!
# enter your withdraw amount 2000000
# your current balance is:  8000000
# **collect your amount and card**
# deposite opreation
#  enter your deposite deposite amount: 12000000
# your money has been successfully desposite.
# Net balance is  20000000
